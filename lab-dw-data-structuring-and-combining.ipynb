# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
# Your code goes here
import pandas as pd
url1 = 'https://raw.githubusercontent.com/claragal/lab-dw-data-cleaning-and-formatting/main/cleaned_insurance_data.csv'
url2 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv'
url3 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv'

# Create the dataframe
cleaned_insurance_df = pd.read_csv(url1)
dataset2_df = pd.read_csv(url2)
dataset3_df = pd.read_csv(url3)

# %%
cleaned_insurance_df.head(10)
# Out:
#   customer       state gender             education  customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                   588174
# 1  QZ44356     Arizona      F              Bachelor                   697953
# 2  AI49188      Nevada      F              Bachelor                  1288743
# 3  WW63253  California      M              Bachelor                   764586
# 4  GA49547  Washington      M  High School or Below                   536307
# 5  OC83172      Oregon      F              Bachelor                   825629
# 6  XZ87318      Oregon      F               College                   538089
# 7  CF85061     Arizona      M                Master                   721610
# 8  DY87989      Oregon      M              Bachelor                  2412750
# 9  BQ94931      Oregon      F               College                   738817
#
#    income  monthly_premium_auto  number_of_open_complaints     policy_type  \
# ...

# %%
dataset2_df.head(10)
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
# 5  WL99637     Arizona      M  Bachelor              761413.80%   27293
# 6  UC84059  California      F    Master              689845.53%   70950
# 7  HW62747      Oregon      M   College              229837.92%       0
# 8  BH11344      Oregon      F    Doctor              280669.61%   37009
# 9  TX28465      Nevada      M   College              520611.82%   52629
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00          633.600000
# ...

# %%
from cleaning_functions import clean_data

# Load your dataset (replace 'new_file.csv' with your actual file)
dataset2 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv')

# Apply the cleaning steps to dataset2
cleaned_dataset2 = clean_data(dataset2)

# Save the cleaned data
cleaned_dataset2.to_csv('cleaned_dataset2.csv', index=False)

print("Data cleaned and saved as 'cleaned_dataset2.csv'")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 7
#       4 dataset2 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv')
#       6 # Apply the cleaning steps to dataset2
# ----> 7 cleaned_dataset2 = clean_data(dataset2)
#       9 # Save the cleaned data
#      10 cleaned_dataset2.to_csv('cleaned_dataset2.csv', index=False)
#
# File c:\Users\Pc\Desktop\Ironhack\Labs\lab-dw-data-structuring-and-combining\cleaning_functions.py:43, in clean_data(df)
#      39 """
#      40 Apply all the cleaning and formatting steps on the dataset.
#      41 """
#      42 df = clean_column_names(df)
# ---> 43 df = clean_invalid_values(df)
#      44 df = formatting_data_types(df)
#      45 df = fill_missing_values(df)
#
# ...

# %%
dataset3_df.head(10)
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
# 5  VI78454     Arizona              2750.705045               College      M
# 6  FP59138      Oregon             13024.130120                Master      M
# 7  XN62489      Oregon              2538.626320              Bachelor      M
# 8  GP66031  California              2585.955652               College      F
# 9  IX68587      Nevada              5096.673223                Master      F
#
#    Income  Monthly Premium Auto  Number of Open Complaints     Policy Type  \
# ...

# %%
from cleaning_functions import clean_data

# Load your dataset (replace 'new_file.csv' with your actual file)
dataset3 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv')

# Apply the cleaning steps to dataset2
cleaned_dataset3 = clean_data(dataset3)

# Save the cleaned data
cleaned_dataset3.to_csv('cleaned_dataset3.csv', index=False)

print("Data cleaned and saved as 'cleaned_dataset3.csv'")
# Out:
# Data cleaned and saved as 'cleaned_dataset3.csv'

# %%
url4 = 'C:/Users/Pc/Desktop/Ironhack/Labs/lab-dw-data-structuring-and-combining/cleaned_dataset2.csv'
url5 = 'C:/Users/Pc/Desktop/Ironhack/Labs/lab-dw-data-structuring-and-combining/cleaned_dataset3.csv'

cleaned_dataset2_df = pd.read_csv(url4)
cleaned_dataset3_df = pd.read_csv(url5)

newdataset_df = pd.concat([cleaned_insurance_df, cleaned_dataset2_df, cleaned_dataset3_df], axis=0)
newdataset_df.head(10)
# Out:
#   customer       state gender             education  customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                   588174
# 1  QZ44356     Arizona      F              Bachelor                   697953
# 2  AI49188      Nevada      F              Bachelor                  1288743
# 3  WW63253  California      M              Bachelor                   764586
# 4  GA49547  Washington      M  High School or Below                   536307
# 5  OC83172      Oregon      F              Bachelor                   825629
# 6  XZ87318      Oregon      F               College                   538089
# 7  CF85061     Arizona      M                Master                   721610
# 8  DY87989      Oregon      M              Bachelor                  2412750
# 9  BQ94931      Oregon      F               College                   738817
#
#    income  monthly_premium_auto  number_of_open_complaints     policy_type  \
# ...

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
# Your code goes here
marketing_df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv")

# %%
pd.set_option('display.max_columns', None) # display all columns
marketing_df.head()
# Out:
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective_to_date employmentstatus gender  income  \
# 0     Basic   College        2011-02-18         Employed      M   48029
# 1     Basic   College        2011-01-18       Unemployed      F       0
# 2     Basic  Bachelor        2011-02-10         Employed      M   22139
# 3  Extended   College        2011-01-11         Employed      M   49078
# 4   Premium  Bachelor        2011-01-17    Medical Leave      F   23675
#
#   location_code marital_status  monthly_premium_auto  months_since_last_claim  \
# ...

# %%
marketing_df.columns
# Out:
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type', 'month'],
#       dtype='object')

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
marketing_df.sales_channel.unique()
# Out:
# array(['Agent', 'Call Center', 'Branch', 'Web'], dtype=object)

# %%
# "total revenue" was interpreted as "customer_lifetime_value"

pivot_df1 = round(marketing_df.pivot_table(index="sales_channel", values=["customer_lifetime_value"]), 2)
pivot_df1
# Out:
#                customer_lifetime_value
# sales_channel
# Agent                          8021.81
# Branch                         8060.62
# Call Center                    8110.36
# Web                            7809.12

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
pivot_df2 = round(marketing_df.pivot_table(index="education", columns="gender", values=["customer_lifetime_value"]), 2)
pivot_df2.head(10)
# Out:
#                      customer_lifetime_value
# gender                                     F        M
# education
# Bachelor                             7874.27  7703.60
# College                              7748.82  8052.46
# Doctor                               7328.51  7415.33
# High School or Below                 8675.22  8149.69
# Master                               8157.05  8168.83

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here
data = {
    'month': ['January', 'January', 'February', 'February', 'March', 'March', 'March'],
    'policy_type': ['Auto', 'Home', 'Auto', 'Home', 'Auto', 'Home', 'Life'],
    'complaints_count': [23, 12, 45, 34, 56, 23, 10]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Group by policy_type and month, and sum the complaints
summary_df = df.groupby(['policy_type', 'month']).sum().reset_index()

# Display the long-format table
print(summary_df)
# Out:
#   policy_type     month  complaints_count
# 0        Auto  February                45
# 1        Auto   January                23
# 2        Auto     March                56
# 3        Home  February                34
# 4        Home   January                12
# 5        Home     March                23
# 6        Life     March                10
